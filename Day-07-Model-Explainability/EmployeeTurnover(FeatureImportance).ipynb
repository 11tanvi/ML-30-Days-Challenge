# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score,confusion_matrix
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv("employee_turnover.csv")

# %%
df.head()
df.info()
df.isnull().sum()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Job_Satisfaction                         1350 non-null   float64
#  1   Performance_Rating                       1350 non-null   float64
#  2   Years_At_Company                         1350 non-null   float64
#  3   Work_Life_Balance                        1350 non-null   float64
#  4   Distance_From_Home                       1350 non-null   float64
#  5   Monthly_Income                           1350 non-null   float64
#  6   Education_Level                          1350 non-null   float64
#  7   Age                                      1350 non-null   float64
#  8   Num_Companies_Worked                     1350 non-null   float64
#  9   Employee_Role                            1350 non-null   float64
#  10  Annual_Bonus                             1350 non-null   float64
#  11  Training_Hours                           1350 non-null   float64
#  12  Department                               1350 non-null   float64
#  13  Annual_Bonus_Squared                     1350 non-null   float64
#  14  Annual_Bonus_Training_Hours_Interaction  1350 non-null   float64
#  15  Employee_Turnover                        1350 non-null   int64
# dtypes: float64(15), int64(1)
# memory usage: 168.9 KB
# Index(['Job_Satisfaction', 'Performance_Rating', 'Years_At_Company',
#        'Work_Life_Balance', 'Distance_From_Home', 'Monthly_Income',
#        'Education_Level', 'Age', 'Num_Companies_Worked', 'Employee_Role',
#        'Annual_Bonus', 'Training_Hours', 'Department', 'Annual_Bonus_Squared',
#        'Annual_Bonus_Training_Hours_Interaction', 'Employee_Turnover'],
#       dtype='object')

# %%
x = df.drop("Employee_Turnover",axis = 1)

# %%
y = df["Employee_Turnover"]

# %% [markdown]
# **Data Visualization**

# %%
sns.countplot(x="Employee_Turnover", data=df)
plt.title("Employee Turnover Distribution")
# Out:
# Text(0.5, 1.0, 'Employee Turnover Distribution')

# %% [markdown]
# **Train Test Split**

# %%
#train test split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %% [markdown]
# **Model Training**

# %%
#model 
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)

model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# **Evaluation**

# %%
from sklearn.metrics import ConfusionMatrixDisplay
print("Before Feature Engineering")
Accuracy = print("accuracy_score",accuracy_score(y_test,y_pred))
Precision = print("Precision:", precision_score(y_test, y_pred))
Recall = print("Recall:", recall_score(y_test, y_pred))

ConfusionMatrixDisplay.from_estimator(model, x_test, y_test)
plt.title("Confusion Matrix - Random Forest")
# Out:
# Before Feature Engineering
# accuracy_score 0.9111111111111111
# Precision: 0.9105691056910569
# Recall: 0.896
# Text(0.5, 1.0, 'Confusion Matrix - Random Forest')

# %% [markdown]
# **Feature Importance**

# %%
importances = model.feature_importances_
features = x.columns
feat_df = pd.DataFrame({
    "Feature" : features,
    "Importance" : importances
}).sort_values(by = "Importance",ascending = False)
print(feat_df)
# Out:
#                                     Feature  Importance
# 4                        Distance_From_Home    0.150340
# 0                          Job_Satisfaction    0.133758
# 1                        Performance_Rating    0.129778
# 3                         Work_Life_Balance    0.114701
# 2                          Years_At_Company    0.097784
# 6                           Education_Level    0.043753
# 12                               Department    0.041233
# 9                             Employee_Role    0.040130
# 8                      Num_Companies_Worked    0.038909
# 7                                       Age    0.038487
# 5                            Monthly_Income    0.036325
# 11                           Training_Hours    0.035296
# 14  Annual_Bonus_Training_Hours_Interaction    0.033342
# 13                     Annual_Bonus_Squared    0.033300
# 10                             Annual_Bonus    0.032865

# %%
plt.figure(figsize=(10,6))
plt.barh(feat_df["Feature"], feat_df["Importance"])
plt.title("Feature Importance - Random Forest")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# **Conclusion
# Distance_From_Home,Job Satisfaction and Performance Rating are major factors
# Employee behavior plays a key role in turnover prediction**
